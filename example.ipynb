# %% [markdown]
# ## Calling LLM Review

# %%
import llm_client

# %%
result = llm_client.review_file("/home/haianhlt/Documents/bioturing/testing/kudo/test_data/test.py")

# %%
import json
print(json.dumps(result, indent=2))
# Out:
# {
#   "summary": {
#     "overall_assessment": "The code is generally well-structured and functional for its defined operations, but it contains potential risks related to data validation and error handling robustness, and includes some unused elements.",
#     "confidence": "high"
#   },
#   "bugs": [],
#   "risks": [
#     {
#       "description": "The `Rectangle` class (lines 31-34) allows initialization with negative width or height values. This will result in a negative area calculation, which is logically incorrect for a geometric area and can lead to misleading results."
#     },
#     {
# ...
