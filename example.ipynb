# %% [markdown]
# ## Calling LLM Review

# %%
from llm_review import review_file
result = review_file("/home/haianhlt/Documents/bioturing/testing/kudo/test_data/test.py")
print(result)
# Out:
# {'summary': {'overall_assessment': 'The code implements basic object-oriented patterns for shape area calculation. Key areas for improvement include precision in constant definitions and robustness of error handling, particularly in `total_area`, to prevent misleading results.', 'confidence': 'high'}, 'bugs': [], 'risks': [{'description': 'The `PI` constant is defined with limited precision (3.14159). This can lead to minor inaccuracies in calculations performed by `area_of_circle` compared to using `math.pi`.'}, {'description': "The `total_area` function catches a broad `Exception` during the calculation of individual shape areas. This can mask specific errors (e.g., `NotImplementedError` if a raw `Shape` instance is passed, or `ValueError` from other shape implementations), leading to a partial sum being returned without clear indication to the caller that some shapes failed to compute. This makes the 'total' value potentially misleading."}, {'description': "The `total_area` functi
# ...

# %%
import json
print(json.dumps(result, indent=2))
# Out:
# {
#   "summary": {
#     "overall_assessment": "The code implements basic object-oriented patterns for shape area calculation. Key areas for improvement include precision in constant definitions and robustness of error handling, particularly in `total_area`, to prevent misleading results.",
#     "confidence": "high"
#   },
#   "bugs": [],
#   "risks": [
#     {
#       "description": "The `PI` constant is defined with limited precision (3.14159). This can lead to minor inaccuracies in calculations performed by `area_of_circle` compared to using `math.pi`."
#     },
#     {
# ...
